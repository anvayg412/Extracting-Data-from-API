# %%
import requests
import pandas as pd
import json

# %%
url="https://api.themoviedb.org/3/movie/top_rated?api_key=e6c4eb1bc805e2cf433b4f5365690487&language=en-US&page=1"
response_movie=requests.get(url)
data=response_movie.json()
data['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/5hNcsnMkwU2LknLoru73c76el3z.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 19404,
#   'original_language': 'hi',
#   'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#   'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#   'popularity': 27.295,
#   'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#   'release_date': '1995-10-20',
#   'title': 'Dilwale Dulhania Le Jayenge',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 3368},
#  {'adult': False,
#   'backdrop_path': '/iNh3BivHyg5sQRPP1KOkzguEX0H.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
# ...

# %%
lst1=[]
new_lst=[]
count=0
for i in data['results']:
    for j,k in i.items():
        lst1.append(j)
for i in lst1:
    if i not in new_lst:
        new_lst.append(i)
print(new_lst)
# Out:
# ['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'release_date', 'title', 'video', 'vote_average', 'vote_count']

# %%
df=pd.DataFrame(data['results'])[new_lst]
#df['genre_ids']=str(df['genre_ids'])
#df['genre_id']=df['genre_ids'].str.replace("[","").str.replace("]","")
#df['genre_ids'][0]
for i in range(len(df['genre_ids'])):
    df['genre_ids'][i]=str(df['genre_ids'][i])
df['genre_ids']=df['genre_ids'].str.replace("[","").str.replace(']','')
df['genre_ids'][0]
# Out:
# C:\Users\anvay\AppData\Local\Temp/ipykernel_12832/1727473526.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genre_ids'][i]=str(df['genre_ids'][i])
# C:\Users\anvay\AppData\Local\Temp/ipykernel_12832/1727473526.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['genre_ids']=df['genre_ids'].str.replace("[","").str.replace(']','')
# '35, 18, 10749'

# %%
df.dtypes
# Out:
# adult                          bool
# backdrop_path                object
# genre_ids                    object
# id                            int64
# original_language            object
# original_title               object
# overview                     object
# popularity                  float64
# poster_path                  object
# release_date         datetime64[ns]
# title                        object
# video                          bool
# vote_average                float64
# vote_count                    int64
# dtype: object

# %%
df['release_date']=df['release_date'].astype('datetime64[ns]')

# %%
import numpy as np
import mysql.connector
from sqlalchemy import create_engine

# %%
conn=mysql.connector.connect(host="localhost",user="root",password="password")
cur=conn.cursor()
#cur.execute("Create database test_database")
cur.execute("Show databases")
row=cur.fetchone()
while row:
    print(row)
    row=cur.fetchone()
cur.close
conn.close
# Out:
# ('abc',)
# ('class',)
# ('class_activity',)
# ('class_activity_1',)
# ('cs',)
# ('dummy',)
# ('final',)
# ('final_exam',)
# ('finall',)
# ('homework',)
# ('homework_assignment',)
# ('hw',)
# ('hw1',)
# ('hw2',)
# ('information_schema',)
# ('mysql',)
# ('new',)
# ('performance_schema',)
# ('sales',)
# ('salesdata',)
# ('salesdata_1',)
# ('salesdata_2',)
# ('sys',)
# ('test_database',)
# <bound method MySQLConnection.close of <mysql.connector.connection.MySQLConnection object at 0x0000020C2C5B5FD0>>

# %%
df
# Out:
#     adult                     backdrop_path             genre_ids      id  \
# 0   False  /5hNcsnMkwU2LknLoru73c76el3z.jpg         35, 18, 10749   19404
# 1   False  /iNh3BivHyg5sQRPP1KOkzguEX0H.jpg                18, 80     278
# 2   False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg                18, 80     238
# 3   False  /jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg                 10749  724089
# 4   False  /loRmRzQXZeqG78TqZuyvSlEQfZb.jpg         18, 36, 10752     424
# 5   False  /l5K9elugftlcyIHHm4nylvsn26X.jpg                    18  255709
# 6   False  /w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg                 10749  696374
# 7   False  /poec6RqOKY9iSiIUmfyfPfiLtvB.jpg                18, 80     240
# 8   False  /fQq1FWp1rC89xDrRMuyFJdFUdMd.jpg             10749, 35  761053
# 9   False  /mMtUybQ6hL24FXo0F3Z4j2KG7kZ.jpg         10749, 16, 18  372058
# 10  False  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg         16, 10751, 14     129
# 11  False   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg            35, 53, 18  496243
# ...

# %%
conn=mysql.connector.connect(host="localhost",user="root",password="password",database="test_database")
engine = create_engine('mysql+mysqlconnector://root:password@localhost:3306/test_database', echo=False)
df.to_sql(name='tmdb', con=engine, if_exists = 'replace', index=False)
#pd.read_sql_query("Select * from tmdb",conn)

# %%
pd.read_sql_query("select * from tmdb where original_language in ('hi','en')",conn)
# Out:
#     adult                     backdrop_path       genre_ids      id  \
# 0       0  /5hNcsnMkwU2LknLoru73c76el3z.jpg   35, 18, 10749   19404
# 1       0  /iNh3BivHyg5sQRPP1KOkzguEX0H.jpg          18, 80     278
# 2       0  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg          18, 80     238
# 3       0  /jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg           10749  724089
# 4       0  /loRmRzQXZeqG78TqZuyvSlEQfZb.jpg   18, 36, 10752     424
# 5       0  /w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg           10749  696374
# 6       0  /poec6RqOKY9iSiIUmfyfPfiLtvB.jpg          18, 80     240
# 7       0  /fQq1FWp1rC89xDrRMuyFJdFUdMd.jpg       10749, 35  761053
# 8       0  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              18     389
# 9       0  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg      14, 18, 80     497
# 10      0  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  18, 28, 80, 53     155
# 11      0  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          53, 80     680
# 12      0  /lXhgCODAbBXL5buk9yEmTpOoOgR.jpg      12, 14, 28     122
#
# ...

# %%
pd.read_sql_query("select * from tmdb where vote_average>=8 and popularity>90",conn)
# Out:
#    adult                     backdrop_path             genre_ids      id  \
# 0      0  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg                18, 80     238
# 1      0  /mMtUybQ6hL24FXo0F3Z4j2KG7kZ.jpg         10749, 16, 18  372058
# 2      0  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg         16, 10751, 14     129
# 3      0   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg            35, 53, 18  496243
# 4      0  /u1wHUA0R48FH4WV3sGqjwx3aNZm.jpg  16, 18, 10402, 10749  632632
# 5      0  /1EAxNqdkVnp48a7NUuNBHGflowM.jpg       16, 28, 878, 18  283566
# 6      0  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg        18, 28, 80, 53     155
# 7      0  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg                53, 80     680
# 8      0  /lXhgCODAbBXL5buk9yEmTpOoOgR.jpg            12, 14, 28     122
#
#   original_language                                 original_title  \
# 0                en                                  The Godfather
# 1                ja                                          君の名は。
# ...

# %%
pd.read_sql_query("select * from tmdb where release_date>='1994-09-10'",conn)
# Out:
#     adult                     backdrop_path             genre_ids      id  \
# 0       0  /5hNcsnMkwU2LknLoru73c76el3z.jpg         35, 18, 10749   19404
# 1       0  /iNh3BivHyg5sQRPP1KOkzguEX0H.jpg                18, 80     278
# 2       0  /jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg                 10749  724089
# 3       0  /l5K9elugftlcyIHHm4nylvsn26X.jpg                    18  255709
# 4       0  /w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg                 10749  696374
# 5       0  /fQq1FWp1rC89xDrRMuyFJdFUdMd.jpg             10749, 35  761053
# 6       0  /mMtUybQ6hL24FXo0F3Z4j2KG7kZ.jpg         10749, 16, 18  372058
# 7       0  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg         16, 10751, 14     129
# 8       0   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg            35, 53, 18  496243
# 9       0  /u1wHUA0R48FH4WV3sGqjwx3aNZm.jpg  16, 18, 10402, 10749  632632
# 10      0  /1EAxNqdkVnp48a7NUuNBHGflowM.jpg       16, 28, 878, 18  283566
# 11      0  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg            14, 18, 80     497
# ...
